# %% [markdown]
# # Named Entity Recognition with BERT (CoNLL-2003)
#
# Fine-tuning **`bert-base-uncased`** for token-level **Named Entity Recognition** on the
# **CoNLL-2003** benchmark (PER, ORG, LOC, MISC). The notebook walks through the full pipeline:
# tokenization with sub-word label alignment, fine-tuning, `seqeval` evaluation, and inference.
#
# > **Tip:** run on a GPU (e.g. Colab **T4**) for reasonable training time.

# %% [markdown]
# ## 1 · Setup

# %%
# %%capture
# !pip install -U datasets transformers evaluate seqeval

# %%
import numpy as np
from datasets import load_dataset
from transformers import (
    BertTokenizerFast, AutoModelForTokenClassification,
    TrainingArguments, Trainer, DataCollatorForTokenClassification, pipeline,
)
import evaluate

# %% [markdown]
# ## 2 · Load the dataset and tokenizer

# %%
dataset = load_dataset("eriktks/conll2003")
tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")

label_list = dataset["train"].features["ner_tags"].feature.names
id2label = {i: l for i, l in enumerate(label_list)}
label2id = {l: i for i, l in enumerate(label_list)}
print("Labels:", label_list)

# %% [markdown]
# ## 3 · Tokenize and align labels
#
# BERT splits words into sub-word tokens, so each original NER tag must be re-aligned to the
# sub-words. Special tokens get the ignore index `-100`; by default every sub-word of a word
# inherits the word's label.

# %%
def tokenize_and_align_labels(examples, label_all_tokens=True):
    tokenized = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)
    aligned_labels = []
    for i, labels in enumerate(examples["ner_tags"]):
        word_ids = tokenized.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(labels[word_idx])
            else:
                label_ids.append(labels[word_idx] if label_all_tokens else -100)
            previous_word_idx = word_idx
        aligned_labels.append(label_ids)
    tokenized["labels"] = aligned_labels
    return tokenized

tokenized_datasets = dataset.map(tokenize_and_align_labels, batched=True)

# %% [markdown]
# ## 4 · Model and metrics

# %%
model = AutoModelForTokenClassification.from_pretrained(
    "bert-base-uncased", num_labels=len(label_list), id2label=id2label, label2id=label2id,
)

seqeval = evaluate.load("seqeval")

def compute_metrics(eval_preds):
    logits, labels = eval_preds
    preds = np.argmax(logits, axis=2)
    true_preds = [
        [label_list[p] for p, l in zip(pred, lab) if l != -100]
        for pred, lab in zip(preds, labels)
    ]
    true_labels = [
        [label_list[l] for p, l in zip(pred, lab) if l != -100]
        for pred, lab in zip(preds, labels)
    ]
    results = seqeval.compute(predictions=true_preds, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %% [markdown]
# ## 5 · Train

# %%
args = TrainingArguments(
    output_dir="ner-bert-conll2003",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_steps=50,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    report_to="none",
)

data_collator = DataCollatorForTokenClassification(tokenizer)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

trainer.train()

# %% [markdown]
# ## 6 · Evaluate on the test split

# %%
metrics = trainer.evaluate(tokenized_datasets["test"])
print({k: round(v, 4) for k, v in metrics.items() if isinstance(v, float)})

# %% [markdown]
# ## 7 · Save the fine-tuned model

# %%
trainer.save_model("ner_model")
tokenizer.save_pretrained("ner_model")

# %% [markdown]
# ## 8 · Inference

# %%
ner_pipeline = pipeline(
    "ner", model="ner_model", tokenizer="ner_model", aggregation_strategy="simple"
)

sentence = (
    "Apple Inc. is a technology company based in Cupertino, California. "
    "Tim Cook is the CEO of Apple. The company was founded in 1976 by "
    "Steve Jobs, Steve Wozniak, and Ronald Wayne."
)

for ent in ner_pipeline(sentence):
    print(f"{ent['word']:<20} {ent['entity_group']:<6} {ent['score']:.3f}")
